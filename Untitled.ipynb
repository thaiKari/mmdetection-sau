# %%
import torch
print(torch.__version__)
# Out:
# 1.3.0

# %%
import os
os.listdir('data/data_external/train2020_4d_crop1024')
# Out:
# ['sep19_102MEDIA_DJI_0561_CROPPED_[512][0][1024][1024].npy',
#  'oct19_103MEDIA_DJI_0704_CROPPED_[0][1024][1024][1024].npy',
#  'sep19_101MEDIA_DJI_0352_CROPPED_[2048][1024][1024][1024].npy',
#  'sep19_102MEDIA_DJI_0547_CROPPED_[1024][512][1024][1024].npy',
#  'aug19_101MEDIA_DJI_0705_CROPPED_[1024][1312][1024][1024].npy',
#  'aug19_101MEDIA_DJI_0037_CROPPED_[0][1024][1024][1024].npy',
#  'oct19_103MEDIA_DJI_0728_CROPPED_[512][512][1024][1024].npy',
#  'oct19_103MEDIA_DJI_0704_CROPPED_[1536][512][1024][1024].npy',
#  'sep19_101MEDIA_DJI_0404_CROPPED_[1536][512][1024][1024].npy',
#  'aug19_102MEDIA_DJI_0668_CROPPED_[2176][512][1024][1024].npy',
#  'aug19_102MEDIA_DJI_0324_CROPPED_[2048][512][1024][1024].npy',
#  'oct19_103MEDIA_DJI_0722_CROPPED_[1024][512][1024][1024].npy',
#  'oct19_103MEDIA_DJI_0134_CROPPED_[0][1024][1024][1024].npy',
#  'oct19_103MEDIA_DJI_0744_CROPPED_[512][0][1024][1024].npy',
#  'oct19_103MEDIA_DJI_0206_CROPPED_[0][1024][1024][1024].npy',
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

im_4d = np.load('data/data_external/train2020_4d_crop1024/oct19_103MEDIA_DJI_0122_CROPPED_[1536][512][1024][1024].npy')
print(im_4d.shape)

plt.figure()
plt.imshow(im_4d[:,:,:3])
# Out:
# (1024, 1024, 4)
